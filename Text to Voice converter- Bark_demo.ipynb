# %% [markdown]
# ## Install

# %%
# install bark (make sure you have torch>=2 for much faster flash-attention)
# !pip install git+https://github.com/suno-ai/bark.git
# Out:
# ...
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-rb4hegrm
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-rb4hegrm
#   Resolved https://github.com/suno-ai/bark.git to commit f4f32d4cd480dfec1c245d258174bc9bde3c2148
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 17.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 44.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Basics

# %%
from bark import SAMPLE_RATE, generate_audio, preload_models
from IPython.display import Audio

preload_models()
# Out:
# text_2.pt:   0%|          | 0.00/5.35G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# coarse_2.pt:   0%|          | 0.00/3.93G [00:00<?, ?B/s]
# fine_2.pt:   0%|          | 0.00/3.74G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
# ...

# %%
text_prompt = """
    We have a silkyaio smooth voice, and tomorrow I will tell you
    about the exercise regimen of the common sloth.
"""
audio_array = generate_audio(text_prompt, history_prompt="v2/en_speaker_1")
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 17/17 [00:19<00:00,  1.15s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """
    I have a silky smooth voice, and today I will tell you
    about the exercise regimen of the common sloth.
"""
audio_array = generate_audio(text_prompt, history_prompt="v2/en_speaker_8")
Audio(audio_array, rate=SAMPLE_RATE)

# %%
text_prompt = """
    मानवता की पहचान गुणों से होती है.. ना कि ऊंचे सिंहासन पर बैठने से...
    महल के उच्च शिखर पर बैठने के बावजूद... कौवे का गरुड़ होना असंभव है।
"""
audio_array = generate_audio(text_prompt, history_prompt="v2/hi_speaker_5")
Audio(audio_array, rate=SAMPLE_RATE)

# %%
text_prompt = """
    मानवता की पहचान गुणों से होती है.. ना कि ऊंचे सिंहासन पर बैठने से... [laughs]
    महल के उच्च शिखर पर बैठने के बावजूद...  कौवे का गरुड़ होना असंभव है।
"""
audio_array = generate_audio(text_prompt, history_prompt="v2/hi_speaker_5")
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 37/37 [00:39<00:00,  1.06s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """
     Hello, my name is Suno. And, uh — and I like pizza. [clears throat]
     But I also have other interests such as playing tic tac toe.
"""
audio_array = generate_audio(text_prompt)
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 34/34 [00:36<00:00,  1.08s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Advanced examples

# %%
text_prompt = """
    Buenos días Miguel. Tu colega piensa que tu alemán es extremadamente malo.
    But I suppose your english isn't terrible.
"""
audio_array = generate_audio(text_prompt)
Audio(audio_array, rate=SAMPLE_RATE)
# Out:
# ...
# 100%|██████████| 36/36 [00:38<00:00,  1.06s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text_prompt = """
    WOMAN: I would like an oatmilk latte please.
    MAN: Wow, that's expensive!
"""
audio_array = generate_audio(text_prompt)
Audio(audio_array, rate=SAMPLE_RATE)
